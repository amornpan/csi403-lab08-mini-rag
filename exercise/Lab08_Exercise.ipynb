# %% [markdown]
# # Lab 08: Mini RAG System - Exercise
#
# **Total Points:** 100 | **Time:** ~45 minutes
#
# Build your own Mini RAG System!
#
# ---

# %% [markdown]
# ## Exercise 1: Load Documents (25 pts)
#
# Create `load_files(filepaths)` that returns list of document dicts.
#
# Return format: `[{'path': path, 'content': content}, ...]`

# %%
# YOUR CODE HERE
def load_files(filepaths):
    """Load documents from filepaths.
    Return: [{'path': path, 'content': content}, ...]
    """
    pass

# Check your answer
sample_paths = ['../data/rubella.md', '../data/cholera.md']
# docs = load_files(sample_paths)
# print(f'Loaded {len(docs)} documents')

# %%
# Quick check (structure only)
# Uncomment below after implementing
# docs = load_files(sample_paths)
# if docs is not None:
#     print(f'✅ Function returns a value')
#     if isinstance(docs, list):
#         print(f'✅ Function returns a list')
#         print(f'   Number of documents: {len(docs)}')
#     else:
#         print(f'❌ Function should return a list')
# else:
#     print(f'❌ Function returns None')
print('Implement load_files and uncomment the check above')

# %% [markdown]
# ---
#
# ## Exercise 2: Chunk Text (25 pts)
#
# Create `make_chunks(text, size)` that splits text into chunks.

# %%
# YOUR CODE HERE
def make_chunks(text, size):
    """Split text into chunks of given size."""
    pass

# Check your answer
test_text = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'
chunks = make_chunks(test_text, 10)
print(f'Result: {chunks}')

# %%
# Quick check (structure only)
result = make_chunks('ABCDEFGHIJ', 5)
if result is not None:
    print(f'✅ Function returns a value')
    if isinstance(result, list):
        print(f'✅ Function returns a list')
        print(f'   Number of chunks: {len(result)}')
    else:
        print(f'❌ Function should return a list')
else:
    print(f'❌ Function returns None')

# %% [markdown]
# ---
#
# ## Exercise 3: Search Function (25 pts)
#
# Create `find_matches(query, chunks)` that returns chunks containing query (case-insensitive).

# %%
# YOUR CODE HERE
def find_matches(query, chunks):
    """Find chunks containing the query (case-insensitive)."""
    pass

# Check your answer
test_chunks = ['fever and rash', 'diarrhea symptoms', 'high fever']
results = find_matches('fever', test_chunks)
print(f'Result: {results}')

# %%
# Quick check (structure only)
test_chunks = ['fever and rash', 'diarrhea symptoms', 'high fever']
results = find_matches('fever', test_chunks)
if results is not None:
    print(f'✅ Function returns a value')
    if isinstance(results, list):
        print(f'✅ Function returns a list')
        print(f'   Number of matches: {len(results)}')
    else:
        print(f'❌ Function should return a list')
else:
    print(f'❌ Function returns None')

# %% [markdown]
# ---
#
# ## Exercise 4: Complete System (25 pts)
#
# Create `MiniRAG` class with `load()`, `index()`, `search()` methods.

# %%
# YOUR CODE HERE
class MiniRAG:
    def __init__(self):
        self.documents = []
        self.chunks = []
    
    def load(self, filepaths):
        """Load documents from files."""
        pass
    
    def index(self, chunk_size=100):
        """Create chunks from loaded documents."""
        pass
    
    def search(self, query):
        """Search chunks for query."""
        pass

# %%
# Quick check (structure only)
rag = MiniRAG()

# Check class structure
if hasattr(rag, 'documents') and hasattr(rag, 'chunks'):
    print('✅ MiniRAG has documents and chunks attributes')
else:
    print('❌ MiniRAG should have documents and chunks attributes')

if hasattr(rag, 'load') and hasattr(rag, 'index') and hasattr(rag, 'search'):
    print('✅ MiniRAG has load, index, search methods')
else:
    print('❌ MiniRAG should have load, index, search methods')

# Test with manual data
rag.chunks = [
    'Rubella causes fever and rash',
    'Cholera causes diarrhea',
    'Dengue fever is dangerous'
]

results = rag.search('fever')
if results is not None:
    print(f'✅ search() returns a value')
    if isinstance(results, list):
        print(f'✅ search() returns a list')
        print(f'   Number of matches: {len(results)}')
    else:
        print(f'❌ search() should return a list')
else:
    print(f'❌ search() returns None')

# %% [markdown]
# ---
#
# ## 🎉 Finished!
#
# You've built a complete Mini RAG System!
#
# ### What you created:
# 1. Document loader
# 2. Text chunker
# 3. Search function
# 4. Complete RAG class
#
# ### Submit:
# ```bash
# git add . && git commit -m 'Complete Lab 08' && git push
# ```
#
# Check your score in GitHub Actions tab!
